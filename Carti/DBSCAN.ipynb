# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("playlist_exit_ticket.csv")

# %%
df
# Out:
#        playlist                                             tracks  \
# 0    Playlist 1  ['Oops!...I Did It Again', 'All The Small Thin...
# 1    Playlist 2  ["It Wasn't Me", 'Murder On The Dancefloor', '...
# 2    Playlist 3  ['Dilemma', 'Without Me', 'Complicated', 'A Th...
# 3    Playlist 4  ['In Da Club', 'Seven Nation Army', 'Lose Your...
# 4    Playlist 5  ['Yeah! (feat. Lil Jon & Ludacris)', 'This Lov...
# 5    Playlist 6  ['We Belong Together', 'Let Me Love You', 'Fix...
# 6    Playlist 7  ["Hips Don't Lie (feat. Wyclef Jean)", 'Temper...
# 7    Playlist 8  ['Bleeding Love', 'Umbrella', 'Smack That', "B...
# 8    Playlist 9  ['Low (feat. T-Pain)', 'I Kissed A Girl', 'Tak...
# 9   Playlist 10  ['I Gotta Feeling', 'Poker Face', 'Halo', 'Sex...
# 10  Playlist 11  ['Just the Way You Are', 'Love The Way You Lie...
# 11  Playlist 12  ['Rolling in the Deep', 'Moves Like Jagger - S...
# 12  Playlist 13  ['Locked out of Heaven', 'Call Me Maybe', 'We ...
# 13  Playlist 14  ['Mirrors', 'Blurred Lines', 'Royals', 'Anothe...
# 14  Playlist 15  ['Night Changes', 'Counting Stars', 'All of Me...
# 15  Playlist 16  ['Uptown Funk (feat. Bruno Mars)', 'Thinking o...
# 16  Playlist 17  ['Starboy', 'One Dance', 'Love Yourself', 'Clo...
# 17  Playlist 18  ['Shape of You', "Say You Won't Let Go", 'Desp...
# 18  Playlist 19  ['lovely (with Khalid)', 'All The Stars (with ...
# 19  Playlist 20  ['thank u, next', 'bad guy', 'Señorita', '7 ri...
# 20  Playlist 21  ['The Box', 'Blinding Lights', 'positions', 'R...
# 21  Playlist 22  ['deja vu', 'MONTERO (Call Me By Your Name)', ...
# 22  Playlist 23  ['Me Porto Bonito', 'Anti-Hero', 'As It Was', ...
# 23  Playlist 24  ['Kill Bill', 'Seven (feat. Latto)', 'Flowers'...
#
#     average_track_popularity  \
# 0                      65.66
# 1                      66.79
# 2                      64.64
# 3                      66.25
# 4                      67.68
# 5                      68.30
# 6                      67.65
# 7                      69.91
# 8                      69.81
# 9                      70.23
# 10                     68.89
# 11                     70.77
# 12                     72.99
# 13                     72.90
# 14                     73.35
# 15                     76.10
# 16                     75.02
# 17                     78.21
# 18                     75.39
# 19                     76.10
# 20                     61.48
# 21                     63.13
# 22                     68.63
# 23                     76.77
#
#                                                albums  \
# 0   ['Oops!... I Did It Again', 'Enema Of The Stat...
# 1   ['Hot Shot', 'Read My Lips', 'The Marshall Mat...
# 2   ['Nellyville', 'The Eminem Show', 'Let Go', 'B...
# 3   ["Get Rich Or Die Tryin'", 'Elephant', 'Curtai...
# 4   ['Confessions (Expanded Edition)', 'Songs Abou...
# 5   ['The Emancipation of Mimi', 'Let Me Love You'...
# 6   ['Oral Fixation, Vol. 2 (Expanded Edition)', '...
# 7   ['Spirit', 'Good Girl Gone Bad: Reloaded', 'Ko...
# 8   ['Mail on Sunday', 'One Of The Boys', 'Good Gi...
# 9   ['THE E.N.D. (THE ENERGY NEVER DIES)', 'The Fa...
# 10  ['Doo-Wops & Hooligans', 'Recovery', 'The Fame...
# 11  ['21', 'Hands All Over', 'Sorry For Party Rock...
# 12  ['Unorthodox Jukebox', 'Kiss (Deluxe)', 'Some ...
# 13  ['The 20/20 Experience (Deluxe Version)', 'Blu...
# 14  ['FOUR (Deluxe)', 'Native', 'Love In The Futur...
# 15  ['Uptown Special', 'x (Deluxe Edition)', 'See ...
# 16  ['Starboy', 'Views', 'Purpose (Deluxe)', 'Clos...
# 17  ['÷ (Deluxe)', 'Back from the Edge', 'VIDA', '...
# 18  ['lovely (with Khalid)', 'Black Panther The Al...
# 19  ['thank u, next', 'WHEN WE ALL FALL ASLEEP, WH...
# 20  ['Please Excuse Me for Being Antisocial', 'Bli...
# 21  ['deja vu', 'MONTERO (Call Me By Your Name)', ...
# 22  ['Un Verano Sin Ti', 'Midnights', 'As It Was',...
# 23  ['SOS', 'Seven (feat. Latto)', 'Flowers', 'Wha...
#
#                                               artists   top_genre  \
# 0   ['Britney Spears', 'blink-182', 'Faith Hill', ...  'dancepop'
# 1   ['Shaggy', 'Sophie Ellis-Bextor', 'Eminem', 'K...  'dancepop'
# 2   ['Nelly', 'Eminem', 'Avril Lavigne', 'Vanessa ...  'dancepop'
# 3   ['50 Cent', 'The White Stripes', 'Eminem', 'Be...  'dancepop'
# 4   ['USHER', 'Maroon 5', 'Rascal Flatts', 'Britne...  'dancepop'
# 5   ['Mariah Carey', 'Mario', 'Coldplay', 'Rihanna...  'dancepop'
# 6   ['Shakira', 'Sean Paul', 'Nelly Furtado', 'Jus...  'dancepop'
# 7   ['Leona Lewis', 'Rihanna', 'Akon', 'Fergie', '...  'dancepop'
# 8   ['Flo Rida', 'Katy Perry', 'Rihanna', 'Alicia ...       'pop'
# 9   ['Black Eyed Peas', 'Lady Gaga', 'Beyoncé', 'D...       'pop'
# 10  ['Bruno Mars', 'Eminem', 'Lady Gaga', 'Stromae...       'pop'
# 11  ['Adele', 'Maroon 5', 'LMFAO', 'Katy Perry', '...       'pop'
# 12  ['Bruno Mars', 'Carly Rae Jepsen', 'fun.', 'Ri...       'pop'
# 13  ['Justin Timberlake', 'Robin Thicke', 'Lorde',...       'pop'
# 14  ['One Direction', 'OneRepublic', 'John Legend'...       'pop'
# 15  ['Mark Ronson', 'Ed Sheeran', 'Wiz Khalifa', '...       'pop'
# 16  ['The Weeknd', 'Drake', 'Justin Bieber', 'The ...       'pop'
# 17  ['Ed Sheeran', 'James Arthur', 'Luis Fonsi', '...       'pop'
# 18  ['Billie Eilish', 'Kendrick Lamar', 'Imagine D...       'pop'
# 19  ['Ariana Grande', 'Billie Eilish', 'Shawn Mend...       'pop'
# 20  ['Roddy Ricch', 'The Weeknd', 'Ariana Grande',...       'pop'
# 21  ['Olivia Rodrigo', 'Lil Nas X', 'Måneskin', 'S...       'pop'
# 22  ['Bad Bunny', 'Taylor Swift', 'Harry Styles', ...       'pop'
# 23  ['SZA', 'Jung Kook', 'Miley Cyrus', 'Billie Ei...       'pop'
#
#     average_artist_popularity  average_danceability  top_key  average_tempo  \
# 0                       66.17               0.65875        0      122.75544
# 1                       65.65               0.67281        1      115.99193
# 2                       69.48               0.65076        2      119.75400
# 3                       68.93               0.66311        6      116.05242
# 4                       69.48               0.66997        1      117.81705
# 5                       72.62               0.66754        7      114.26774
# 6                       71.56               0.64636        7      116.67285
# 7                       70.45               0.65483        1      124.07822
# 8                       72.70               0.63445       11      125.46693
# 9                       76.11               0.63019        0      127.87172
# 10                      74.56               0.64668        1      118.47478
# 11                      76.60               0.62975       11      125.86606
# 12                      78.68               0.63453        0      123.29756
# 13                      79.28               0.63060        1      117.69925
# 14                      75.59               0.65525        1      119.30899
# 15                      78.89               0.64909        7      121.71692
# 16                      78.45               0.65131        7      117.18515
# 17                      81.23               0.69396       11      120.74486
# 18                      79.35               0.69650        1      118.86209
# 19                      81.16               0.71004        1      120.02957
# 20                      81.85               0.70309        6      120.45447
# 21                      83.65               0.68754        1      119.97148
# 22                      83.91               0.67006        1      125.11037
# 23                      84.83               0.67525        5      121.50287
#
#     top_time_signature
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    4
# 5                    4
# 6                    4
# 7                    4
# 8                    4
# 9                    4
# 10                   4
# 11                   4
# 12                   4
# 13                   4
# 14                   4
# 15                   4
# 16                   4
# 17                   4
# 18                   4
# 19                   4
# 20                   4
# 21                   4
# 22                   4
# 23                   4

# %%
X = df[['average_track_popularity', 'average_tempo']]  # Features (all columns except last)

# %%
model = DBSCAN(eps=3, min_samples=2).fit(X)

# %%
model.labels_
# Out:
# array([-1,  0,  1,  0,  0,  0,  0,  2,  2,  2,  0,  2, -1,  3,  3,  3,  3,
#         3,  3,  3,  1,  1,  2,  3], dtype=int64)

# %%
df
# Out:
#        playlist                                             tracks  \
# 0    Playlist 1  ['Oops!...I Did It Again', 'All The Small Thin...
# 1    Playlist 2  ["It Wasn't Me", 'Murder On The Dancefloor', '...
# 2    Playlist 3  ['Dilemma', 'Without Me', 'Complicated', 'A Th...
# 3    Playlist 4  ['In Da Club', 'Seven Nation Army', 'Lose Your...
# 4    Playlist 5  ['Yeah! (feat. Lil Jon & Ludacris)', 'This Lov...
# 5    Playlist 6  ['We Belong Together', 'Let Me Love You', 'Fix...
# 6    Playlist 7  ["Hips Don't Lie (feat. Wyclef Jean)", 'Temper...
# 7    Playlist 8  ['Bleeding Love', 'Umbrella', 'Smack That', "B...
# 8    Playlist 9  ['Low (feat. T-Pain)', 'I Kissed A Girl', 'Tak...
# 9   Playlist 10  ['I Gotta Feeling', 'Poker Face', 'Halo', 'Sex...
# 10  Playlist 11  ['Just the Way You Are', 'Love The Way You Lie...
# 11  Playlist 12  ['Rolling in the Deep', 'Moves Like Jagger - S...
# 12  Playlist 13  ['Locked out of Heaven', 'Call Me Maybe', 'We ...
# 13  Playlist 14  ['Mirrors', 'Blurred Lines', 'Royals', 'Anothe...
# 14  Playlist 15  ['Night Changes', 'Counting Stars', 'All of Me...
# 15  Playlist 16  ['Uptown Funk (feat. Bruno Mars)', 'Thinking o...
# 16  Playlist 17  ['Starboy', 'One Dance', 'Love Yourself', 'Clo...
# 17  Playlist 18  ['Shape of You', "Say You Won't Let Go", 'Desp...
# 18  Playlist 19  ['lovely (with Khalid)', 'All The Stars (with ...
# 19  Playlist 20  ['thank u, next', 'bad guy', 'Señorita', '7 ri...
# 20  Playlist 21  ['The Box', 'Blinding Lights', 'positions', 'R...
# 21  Playlist 22  ['deja vu', 'MONTERO (Call Me By Your Name)', ...
# 22  Playlist 23  ['Me Porto Bonito', 'Anti-Hero', 'As It Was', ...
# 23  Playlist 24  ['Kill Bill', 'Seven (feat. Latto)', 'Flowers'...
#
#     average_track_popularity  \
# 0                      65.66
# 1                      66.79
# 2                      64.64
# 3                      66.25
# 4                      67.68
# 5                      68.30
# 6                      67.65
# 7                      69.91
# 8                      69.81
# 9                      70.23
# 10                     68.89
# 11                     70.77
# 12                     72.99
# 13                     72.90
# 14                     73.35
# 15                     76.10
# 16                     75.02
# 17                     78.21
# 18                     75.39
# 19                     76.10
# 20                     61.48
# 21                     63.13
# 22                     68.63
# 23                     76.77
#
#                                                albums  \
# 0   ['Oops!... I Did It Again', 'Enema Of The Stat...
# 1   ['Hot Shot', 'Read My Lips', 'The Marshall Mat...
# 2   ['Nellyville', 'The Eminem Show', 'Let Go', 'B...
# 3   ["Get Rich Or Die Tryin'", 'Elephant', 'Curtai...
# 4   ['Confessions (Expanded Edition)', 'Songs Abou...
# 5   ['The Emancipation of Mimi', 'Let Me Love You'...
# 6   ['Oral Fixation, Vol. 2 (Expanded Edition)', '...
# 7   ['Spirit', 'Good Girl Gone Bad: Reloaded', 'Ko...
# 8   ['Mail on Sunday', 'One Of The Boys', 'Good Gi...
# 9   ['THE E.N.D. (THE ENERGY NEVER DIES)', 'The Fa...
# 10  ['Doo-Wops & Hooligans', 'Recovery', 'The Fame...
# 11  ['21', 'Hands All Over', 'Sorry For Party Rock...
# 12  ['Unorthodox Jukebox', 'Kiss (Deluxe)', 'Some ...
# 13  ['The 20/20 Experience (Deluxe Version)', 'Blu...
# 14  ['FOUR (Deluxe)', 'Native', 'Love In The Futur...
# 15  ['Uptown Special', 'x (Deluxe Edition)', 'See ...
# 16  ['Starboy', 'Views', 'Purpose (Deluxe)', 'Clos...
# 17  ['÷ (Deluxe)', 'Back from the Edge', 'VIDA', '...
# 18  ['lovely (with Khalid)', 'Black Panther The Al...
# 19  ['thank u, next', 'WHEN WE ALL FALL ASLEEP, WH...
# 20  ['Please Excuse Me for Being Antisocial', 'Bli...
# 21  ['deja vu', 'MONTERO (Call Me By Your Name)', ...
# 22  ['Un Verano Sin Ti', 'Midnights', 'As It Was',...
# 23  ['SOS', 'Seven (feat. Latto)', 'Flowers', 'Wha...
#
#                                               artists   top_genre  \
# 0   ['Britney Spears', 'blink-182', 'Faith Hill', ...  'dancepop'
# 1   ['Shaggy', 'Sophie Ellis-Bextor', 'Eminem', 'K...  'dancepop'
# 2   ['Nelly', 'Eminem', 'Avril Lavigne', 'Vanessa ...  'dancepop'
# 3   ['50 Cent', 'The White Stripes', 'Eminem', 'Be...  'dancepop'
# 4   ['USHER', 'Maroon 5', 'Rascal Flatts', 'Britne...  'dancepop'
# 5   ['Mariah Carey', 'Mario', 'Coldplay', 'Rihanna...  'dancepop'
# 6   ['Shakira', 'Sean Paul', 'Nelly Furtado', 'Jus...  'dancepop'
# 7   ['Leona Lewis', 'Rihanna', 'Akon', 'Fergie', '...  'dancepop'
# 8   ['Flo Rida', 'Katy Perry', 'Rihanna', 'Alicia ...       'pop'
# 9   ['Black Eyed Peas', 'Lady Gaga', 'Beyoncé', 'D...       'pop'
# 10  ['Bruno Mars', 'Eminem', 'Lady Gaga', 'Stromae...       'pop'
# 11  ['Adele', 'Maroon 5', 'LMFAO', 'Katy Perry', '...       'pop'
# 12  ['Bruno Mars', 'Carly Rae Jepsen', 'fun.', 'Ri...       'pop'
# 13  ['Justin Timberlake', 'Robin Thicke', 'Lorde',...       'pop'
# 14  ['One Direction', 'OneRepublic', 'John Legend'...       'pop'
# 15  ['Mark Ronson', 'Ed Sheeran', 'Wiz Khalifa', '...       'pop'
# 16  ['The Weeknd', 'Drake', 'Justin Bieber', 'The ...       'pop'
# 17  ['Ed Sheeran', 'James Arthur', 'Luis Fonsi', '...       'pop'
# 18  ['Billie Eilish', 'Kendrick Lamar', 'Imagine D...       'pop'
# 19  ['Ariana Grande', 'Billie Eilish', 'Shawn Mend...       'pop'
# 20  ['Roddy Ricch', 'The Weeknd', 'Ariana Grande',...       'pop'
# 21  ['Olivia Rodrigo', 'Lil Nas X', 'Måneskin', 'S...       'pop'
# 22  ['Bad Bunny', 'Taylor Swift', 'Harry Styles', ...       'pop'
# 23  ['SZA', 'Jung Kook', 'Miley Cyrus', 'Billie Ei...       'pop'
#
#     average_artist_popularity  average_danceability  top_key  average_tempo  \
# 0                       66.17               0.65875        0      122.75544
# 1                       65.65               0.67281        1      115.99193
# 2                       69.48               0.65076        2      119.75400
# 3                       68.93               0.66311        6      116.05242
# 4                       69.48               0.66997        1      117.81705
# 5                       72.62               0.66754        7      114.26774
# 6                       71.56               0.64636        7      116.67285
# 7                       70.45               0.65483        1      124.07822
# 8                       72.70               0.63445       11      125.46693
# 9                       76.11               0.63019        0      127.87172
# 10                      74.56               0.64668        1      118.47478
# 11                      76.60               0.62975       11      125.86606
# 12                      78.68               0.63453        0      123.29756
# 13                      79.28               0.63060        1      117.69925
# 14                      75.59               0.65525        1      119.30899
# 15                      78.89               0.64909        7      121.71692
# 16                      78.45               0.65131        7      117.18515
# 17                      81.23               0.69396       11      120.74486
# 18                      79.35               0.69650        1      118.86209
# 19                      81.16               0.71004        1      120.02957
# 20                      81.85               0.70309        6      120.45447
# 21                      83.65               0.68754        1      119.97148
# 22                      83.91               0.67006        1      125.11037
# 23                      84.83               0.67525        5      121.50287
#
#     top_time_signature
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    4
# 5                    4
# 6                    4
# 7                    4
# 8                    4
# 9                    4
# 10                   4
# 11                   4
# 12                   4
# 13                   4
# 14                   4
# 15                   4
# 16                   4
# 17                   4
# 18                   4
# 19                   4
# 20                   4
# 21                   4
# 22                   4
# 23                   4

# %%
silhouette_score(X, model.fit_predict(X))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 silhouette_score(X, model.fit_predict(X))
#
# NameError: name 'silhouette_score' is not defined
