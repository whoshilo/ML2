# %%
import pandas as pd
import json

# %%
'albums_0-999.json'
'mpd.slice.0-999.json'
# Out:
# 'mpd.slice.0-999.json'

# %%
df = pd.read_json('albums_0-999 (1).json')

# %%
df = df.T
df
# Out:
#                        album_type  \
# 6vV5UrXcfyQD1wu4Qo2I9K      album
# 0z7pVBGOD7HCIB7S8eLkLI      album
# 25hVFAxTlDvXbx2X2QkUkE      album
# 6QPkyl04rXwTGlGlcYaRoW      album
# 6NmFmPX56pcLBOFMhIiKvF      album
# ...                           ...
# 2KEQtuVl1cYsTYtVRUrNVi        NaN
# 5jrsRHRAmetu5e7RRBoxj7        NaN
# 3CbNgBzI7r9o0F6VjH9sTY        NaN
# 2dZ7oVNQBeLlpoUYfbEsJP        NaN
# 7D6Y19tjm4DQNch39FeWpO        NaN
#
#                                                                   artists  \
# 6vV5UrXcfyQD1wu4Qo2I9K  [{'external_urls': {'spotify': 'https://open.s...
# 0z7pVBGOD7HCIB7S8eLkLI  [{'external_urls': {'spotify': 'https://open.s...
# 25hVFAxTlDvXbx2X2QkUkE  [{'external_urls': {'spotify': 'https://open.s...
# 6QPkyl04rXwTGlGlcYaRoW  [{'external_urls': {'spotify': 'https://open.s...
# 6NmFmPX56pcLBOFMhIiKvF  [{'external_urls': {'spotify': 'https://open.s...
# ...                                                                   ...
# ...

# %%
df = df.dropna()
df
# Out:
#                          album_type  \
# 6vV5UrXcfyQD1wu4Qo2I9K        album
# 0z7pVBGOD7HCIB7S8eLkLI        album
# 25hVFAxTlDvXbx2X2QkUkE        album
# 6QPkyl04rXwTGlGlcYaRoW        album
# 6NmFmPX56pcLBOFMhIiKvF        album
# ...                             ...
# 1Z1AWzi4XaPFpAQLRUphSg       single
# 5eJCacLF07CBGvE5QbS6C8  compilation
# 0L62zrqwu44InGe9d4EUmQ        album
# 07ZJma4DINFMI3a8XhsJIA        album
# 01gdxhOI5cAkIBsCohcvyP       single
#
#                                                                   artists  \
# 6vV5UrXcfyQD1wu4Qo2I9K  [{'external_urls': {'spotify': 'https://open.s...
# 0z7pVBGOD7HCIB7S8eLkLI  [{'external_urls': {'spotify': 'https://open.s...
# 25hVFAxTlDvXbx2X2QkUkE  [{'external_urls': {'spotify': 'https://open.s...
# 6QPkyl04rXwTGlGlcYaRoW  [{'external_urls': {'spotify': 'https://open.s...
# 6NmFmPX56pcLBOFMhIiKvF  [{'external_urls': {'spotify': 'https://open.s...
# ...                                                                   ...
# ...

# %%
with open('mpd.slice.0-999.json', 'r') as file:
    data = json.load(file)

# Extract the 'playlists' section from the JSON data
playlists = data['playlists']

# Normalize the nested JSON data into a flat table
df2 = pd.json_normalize(playlists, sep='_')

# Display the DataFrame
df2
# Out:
#                  name collaborative  pid  modified_at  num_tracks  num_albums  \
# 0          Throwbacks         false    0   1493424000          52          47
# 1    Awesome Playlist         false    1   1506556800          39          23
# 2             korean          false    2   1505692800          64          51
# 3                 mat         false    3   1501027200         126         107
# 4                 90s         false    4   1401667200          17          16
# ..                ...           ...  ...          ...         ...         ...
# 995               old         false  995   1507852800          41          40
# 996              Daze         false  996   1479254400          17          17
# 997               rap         false  997   1410307200         119          98
# 998           Country         false  998   1507939200         108          75
# 999   thinking of you         false  999   1507766400          44          43
#
# ...

# %%
with open('mpd.slice.999000-999999.json', 'r') as file:
    data = json.load(file)

# Extract the 'playlists' section from the JSON data
playlists = data['playlists']

# Normalize the nested JSON data into a flat table
df3 = pd.json_normalize(playlists, sep='_')

# Display the DataFrame
df3
# Out:
#                  name collaborative     pid  modified_at  num_tracks  \
# 0               Study         false  999000   1468800000          28
# 1               Megan         false  999001   1467504000          14
# 2                 tbd         false  999002   1473984000          64
# 3    Writing Playlist         false  999003   1450137600         188
# 4      Drinking music         false  999004   1440633600          71
# ..                ...           ...     ...          ...         ...
# 995            Praise         false  999995   1409529600          32
# 996           Worship         false  999996   1475625600         122
# 997               Sex         false  999997   1498176000          24
# 998                ✝️         false  999998   1506816000          11
# 999             BANDA         false  999999   1433116800         110
#
#      num_albums  num_followers  \
# 0            18              1
# 1            14              2
# 2            53              1
# ...

# %%
tdf3 = []
for i in df3['tracks']:
    tdf3.append(i)

# %%
tdf3 = pd.DataFrame(tdf3)
tdf3
# Out:
#                                                    0    \
# 0    {'pos': 0, 'artist_name': 'Yiruma', 'track_uri...
# 1    {'pos': 0, 'artist_name': 'The Dustbowl Reviva...
# 2    {'pos': 0, 'artist_name': 'Broods', 'track_uri...
# 3    {'pos': 0, 'artist_name': 'Talib Kweli', 'trac...
# 4    {'pos': 0, 'artist_name': 'Baauer', 'track_uri...
# ..                                                 ...
# 995  {'pos': 0, 'artist_name': 'Unspoken', 'track_u...
# 996  {'pos': 0, 'artist_name': 'Pax217', 'track_uri...
# 997  {'pos': 0, 'artist_name': 'Romeo Santos', 'tra...
# 998  {'pos': 0, 'artist_name': 'Hillsong United', '...
# 999  {'pos': 0, 'artist_name': 'Banda Los Recoditos...
#
#                                                    1    \
# 0    {'pos': 1, 'artist_name': 'Frédéric Chopin', '...
# 1    {'pos': 1, 'artist_name': 'Ginuwine', 'track_u...
# 2    {'pos': 1, 'artist_name': 'Kent Jones', 'track...
# 3    {'pos': 1, 'artist_name': 'Lea Salonga', 'trac...
# ...

# %%
pd.Series(tdf3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pd.Series(tdf3)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:633, in sanitize_array(data, index, dtype, copy, allow_2d)
#     631     else:
#     632         data = np.array(data, copy=copy)
# --> 633     return sanitize_array(
#     634         data,
#     635         index=index,
#     636         dtype=dtype,
#     637         copy=False,
#     638         allow_2d=allow_2d,
#     639     )
# ...

# %%
with open('mpd.slice.99000-99999.json', 'r') as file:
    data = json.load(file)

# Extract the 'playlists' section from the JSON data
playlists = data['playlists']

# Normalize the nested JSON data into a flat table
df4 = pd.json_normalize(playlists, sep='_')

# Display the DataFrame
df4.head(10)

# %%
tdf4 = []
for i in df4['tracks']:
    tdf4.append(i)

# %%
tdf4['tracks']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 tdf4['tracks']
#
# NameError: name 'tdf4' is not defined

# %%
tdf4 = pd.DataFrame(tdf4)
tdf4.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 tdf4 = pd.DataFrame(tdf4)
#       2 tdf4.head()
#
# NameError: name 'tdf4' is not defined

# %%
tdf = pd.merge

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df4.head()
# Out:
#           name collaborative    pid  modified_at  num_tracks  num_albums  \
# 0        Stuff         false  99000   1504310400         170          81
# 1  Lovers Rock         false  99001   1451520000         112          81
# 2       jammin         false  99002   1461196800         130         105
# 3       summer         false  99003   1507680000          55          45
# 4          25%         false  99004   1506729600          13          13
#
#    num_followers                                             tracks  \
# 0              1  [{'pos': 0, 'artist_name': 'Fall Out Boy', 'tr...
# 1              1  [{'pos': 0, 'artist_name': 'Gentleman', 'track...
# 2              4  [{'pos': 0, 'artist_name': 'The Allman Brother...
# 3              1  [{'pos': 0, 'artist_name': 'Miley Cyrus', 'tra...
# 4              1  [{'pos': 0, 'artist_name': 'Maluma', 'track_ur...
#
#    num_edits  duration_ms  num_artists description
# 0         23     38548928           43         NaN
# ...

# %%
dfA = pd.concat([df2, df3])

# %%
dfA.head()
# Out:
#                name collaborative  pid  modified_at  num_tracks  num_albums  \
# 0        Throwbacks         false    0   1493424000          52          47
# 1  Awesome Playlist         false    1   1506556800          39          23
# 2           korean          false    2   1505692800          64          51
# 3               mat         false    3   1501027200         126         107
# 4               90s         false    4   1401667200          17          16
#
#    num_followers                                             tracks  \
# 0              1  [{'pos': 0, 'artist_name': 'Missy Elliott', 't...
# 1              1  [{'pos': 0, 'artist_name': 'Survivor', 'track_...
# 2              1  [{'pos': 0, 'artist_name': 'Hoody', 'track_uri...
# 3              1  [{'pos': 0, 'artist_name': 'Camille Saint-Saën...
# 4              2  [{'pos': 0, 'artist_name': 'The Smashing Pumpk...
#
#    num_edits  duration_ms  num_artists description
# ...

# %%
file_paths = [
    'mpd.slice.0-999.json',
    'mpd.slice.99000-99999.json',
    'mpd.slice.995000-995999.json',
    'mpd.slice.996000-996999.json',
    'mpd.slice.997000-997999.json',
    'mpd.slice.998000-998999.json',
    'mpd.slice.999000-999999.json'
]

all_data = []

for file_path in file_paths:
    with open (file_path, 'r') as file:
        data = json.load(file)
        for playlist in data['playlists']:
            playlist_name = playlist['name']
            playlist_desc = playlist.get('description', '')
            for track in playlist['tracks']:
                all_data.append({
                    'playlist_name': playlist_name,
                    'playlist_desc': playlist_desc,
                    'position_in_playlist': track['pos'],
                    'track_name': track['track_name'],
                    'artist_name': track['artist_name'],
                    'duration_ms': track['duration_ms'],
                    'album_name': track['album_name']
                })
xdf = pd.DataFrame(all_data)

# %%
xdf
